# %%
print('hello world')
# Out:
# hello world

# %%
a = 10
b = 20
a + b
# Out:
# 30

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])

# %%
import numpy as np

x = np.array(range(1,10))
y = x ** 2

import matplotlib.pyplot as plt
plt.plot(x, y)
